# %%
# %load_ext dotenv
# %dotenv

# %%
from langchain_openai import ChatOpenAI
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser

# %%
chat = ChatOpenAI(model_name = 'gpt-4',
                  model_kwargs = {'seed':365},
                  temperature = 0,
                  max_tokens = 500,
                  streaming=True)
# Out:
# /Users/sahilnagpal/Library/Python/3.9/lib/python/site-packages/IPython/core/interactiveshell.py:3490: UserWarning: Parameters {'seed'} should be specified explicitly. Instead they were passed in as part of `model_kwargs` parameter.
#   if await self.run_code(code, result, async_=asy):

# %%
chat_template = ChatPromptTemplate.from_messages([
    ("human","I have recently bought a {racket}, can you suggest some {nameType} for it")
])

# %%
chain = chat_template | chat

# %%
response = chain.stream({'racket':'baybolat','nameType':'hard hitter'})

# %%
for i in response:
    print(i.content, end="")
# Out:
# If you're looking for a hard-hitting player to use your Baybolat tennis racket, consider these professional players known for their powerful shots:
#
# 1. Serena Williams: Known for her powerful and aggressive play, Serena Williams is considered one of the greatest tennis players of all time. Her serve is particularly strong, often reaching speeds of over 120 mph.
#
# 2. Rafael Nadal: Known as the "King of Clay," Nadal is famous for his powerful forehand and aggressive play. His strength and endurance make him a formidable opponent on any surface.
#
# 3. Novak Djokovic: Djokovic is known for his ability to return serve, often turning defense into offense with his powerful groundstrokes. His backhand is particularly strong and accurate.
#
# 4. Juan Martin del Potro: Known for his powerful forehand, del Potro is considered one of the hardest hitters in the game. His serve is also very strong, often reaching speeds of over 130 mph.
#
# 5. Stan Wawrinka: Wawrinka is known for his powerful backhand and aggressive play. His strength and precision make him a dangerous opponent on any surface.
#
# 6. Naomi Osaka: Known for her aggressive play and powerful serve, Osaka is one of the hardest hitters in women's tennis. Her groundstrokes are also very strong and accurate.
#
# Remember, a racket is only as good as the player using it. Practice regularly to improve your strength and technique.
